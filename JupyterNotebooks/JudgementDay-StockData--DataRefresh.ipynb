# %%
import os
from dotenv import load_dotenv
from pathlib import Path
import hw2fintools


load_dotenv()

# Common Variables & Dataframes
judgement_day = os.environ.get('judgement_day')
judgement_day_stock_data = os.path.join(judgement_day, 'StockData')
df_0 = hw2fintools.get_df_stock_watch_list()
ticker_list = df_0['Ticker']

# %%
# Directory Check & Update
for ticker in ticker_list:
    dir_path = Path(os.path.join(judgement_day_stock_data, ticker))
    os.makedirs(dir_path, exist_ok=True)
