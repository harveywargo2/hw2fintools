# %%
from hw2fintools import gurufocus as gf
import os
from dotenv import load_dotenv
import pandas as pd
import re
import numpy as np


load_dotenv()
path_stockdata = os.path.join(os.environ.get('judgement_day'), 'Data--StockWatchList')
date_pattern = r"(\d\d\d\d-\d\d-\d\d)--"

ticker_list = os.listdir(path_stockdata)

# %%
for item in ticker_list:
    loc = 0
    if item.startswith('._'):
        ticker_list.remove(item)

ticker_list.sort()

process_df = pd.DataFrame(ticker_list, columns=['Ticker'])
process_df
# Out:
#    Ticker
# 0    AAPL
# 1    ABBV
# 2     ADM
# 3     ADP
# 4     AMD
# ..    ...
# 88      V
# 89     VZ
# 90    WMT
# 91    XOM
# 92    ZTS
#
# [93 rows x 1 columns]

# %%
process_df['DivFile'] = ''
process_df['DivData'] = False
process_df['PriceFile'] = ''
process_df['PriceData'] = False
process_df['DateMatch'] = ''

process_df
# Out:
#    Ticker DivFile  DivData PriceFile  PriceData DateMatch
# 0    AAPL            False                False
# 1    ABBV            False                False
# 2     ADM            False                False
# 3     ADP            False                False
# 4     AMD            False                False
# ..    ...     ...      ...       ...        ...       ...
# 88      V            False                False
# 89     VZ            False                False
# 90    WMT            False                False
# 91    XOM            False                False
# 92    ZTS            False                False
#
# [93 rows x 6 columns]

# %%
for index, row in process_df.iterrows():
    path_ticker = os.path.join(path_stockdata, row['Ticker'])
    div_list = []
    price_list = []

    for item in os.listdir(path_ticker):
        if 'gf-raw-dividend_history' in item and item.endswith('.csv') and not item.startswith('._'):
            div_list.append(item)
        elif 'gf-raw-price_history' in item and item.endswith('.csv') and not item.startswith('._'):
            price_list.append(item)

    div_list_sorted = sorted(div_list, reverse=True)
    div_current = div_list_sorted[0]
    process_df.loc[index, 'DivFile'] = div_current

    price_list_sorted = sorted(price_list, reverse=True)
    price_current = price_list_sorted[0]
    process_df.loc[index, 'PriceFile'] = price_current

    div_df = pd.read_csv(os.path.join(path_ticker, div_current))

    div_len = len(div_df)

    if div_len <= 20:
        process_df.loc[index, 'DivData'] = False
    else:
        process_df.loc[index, 'DivData'] = True

    price_df = pd.read_csv(os.path.join(path_ticker, price_current))

    if price_df.empty:
        process_df.loc[index, 'PriceData'] = False
    else:
        process_df.loc[index, 'PriceData'] = True

    div_date = re.search(date_pattern, div_current)
    price_date = re.search(date_pattern, price_current)

    div_match = div_date.group(1)
    price_match = price_date.group(1)

    if div_match == price_match:
        process_df.loc[index, 'DateMatch'] = True
    else:
        process_df.loc[index, 'DateMatch'] = False

# %%
process_df
# Out:
#    Ticker                                        DivFile  DivData  \
# 0    AAPL  2025-12-01--AAPL--gf-raw-dividend_history.csv     True
# 1    ABBV  2025-12-01--ABBV--gf-raw-dividend_history.csv     True
# 2     ADM   2025-12-01--ADM--gf-raw-dividend_history.csv     True
# 3     ADP   2025-12-01--ADP--gf-raw-dividend_history.csv     True
# 4     AMD   2025-12-09--AMD--gf-raw-dividend_history.csv    False
# ..    ...                                            ...      ...
# 88      V     2025-12-01--V--gf-raw-dividend_history.csv     True
# 89     VZ    2025-12-01--VZ--gf-raw-dividend_history.csv     True
# 90    WMT   2025-12-01--WMT--gf-raw-dividend_history.csv     True
# 91    XOM   2025-12-01--XOM--gf-raw-dividend_history.csv     True
# 92    ZTS   2025-12-01--ZTS--gf-raw-dividend_history.csv     True
#
#                                      PriceFile  PriceData DateMatch
# 0   2025-12-01--AAPL--gf-raw-price_history.csv       True      True
# 1   2025-12-01--ABBV--gf-raw-price_history.csv       True      True
# 2    2025-12-01--ADM--gf-raw-price_history.csv       True      True
# 3    2025-12-01--ADP--gf-raw-price_history.csv       True      True
# 4    2025-12-09--AMD--gf-raw-price_history.csv       True      True
# ..                                         ...        ...       ...
# 88     2025-12-01--V--gf-raw-price_history.csv       True      True
# 89    2025-12-01--VZ--gf-raw-price_history.csv       True      True
# 90   2025-12-01--WMT--gf-raw-price_history.csv       True      True
# 91   2025-12-01--XOM--gf-raw-price_history.csv       True      True
# 92   2025-12-01--ZTS--gf-raw-price_history.csv       True      True
#
# [93 rows x 6 columns]

# %%
mask = (process_df['DivData'] == True) & (process_df['PriceData'] == True) & (process_df['DateMatch'] == True)
auto_run_df = process_df[mask].copy()
auto_run_df
# Out:
#    Ticker                                        DivFile  DivData  \
# 0    AAPL  2025-12-01--AAPL--gf-raw-dividend_history.csv     True
# 1    ABBV  2025-12-01--ABBV--gf-raw-dividend_history.csv     True
# 2     ADM   2025-12-01--ADM--gf-raw-dividend_history.csv     True
# 3     ADP   2025-12-01--ADP--gf-raw-dividend_history.csv     True
# 5     AMT   2025-12-01--AMT--gf-raw-dividend_history.csv     True
# ..    ...                                            ...      ...
# 88      V     2025-12-01--V--gf-raw-dividend_history.csv     True
# 89     VZ    2025-12-01--VZ--gf-raw-dividend_history.csv     True
# 90    WMT   2025-12-01--WMT--gf-raw-dividend_history.csv     True
# 91    XOM   2025-12-01--XOM--gf-raw-dividend_history.csv     True
# 92    ZTS   2025-12-01--ZTS--gf-raw-dividend_history.csv     True
#
#                                      PriceFile  PriceData DateMatch
# 0   2025-12-01--AAPL--gf-raw-price_history.csv       True      True
# 1   2025-12-01--ABBV--gf-raw-price_history.csv       True      True
# 2    2025-12-01--ADM--gf-raw-price_history.csv       True      True
# 3    2025-12-01--ADP--gf-raw-price_history.csv       True      True
# 5    2025-12-01--AMT--gf-raw-price_history.csv       True      True
# ..                                         ...        ...       ...
# 88     2025-12-01--V--gf-raw-price_history.csv       True      True
# 89    2025-12-01--VZ--gf-raw-price_history.csv       True      True
# 90   2025-12-01--WMT--gf-raw-price_history.csv       True      True
# 91   2025-12-01--XOM--gf-raw-price_history.csv       True      True
# 92   2025-12-01--ZTS--gf-raw-price_history.csv       True      True
#
# [89 rows x 6 columns]

# %%
for index, row in auto_run_df.iterrows():
    path_ticker = os.path.join(path_stockdata, row['Ticker'])
    div_path = os.path.join(path_ticker, row['DivFile'])
    price_path = os.path.join(path_ticker, row['PriceFile'])

    print(row['Ticker'] + '--Start')

    div_df0 = gf.div_hist_s1v1(div_path)
    price_df0 = gf.price_hist_s2v1(price_path)

    div_df1 = div_df0.loc[div_df0['DivType'] == 'regular']
    div_df1 = div_df1.drop(columns=['DivRecordDate', 'DivDeclareDate', 'DivPayDate'])
    div_df1 = div_df1.rename(columns={'ExDivDate': 'Date'})

    merged_df0 = pd.merge(price_df0, div_df1, on='Date', how='left')
    merged_df0['DivAmount'] = merged_df0['DivAmount'].fillna(0)
    merged_df0['DivFrequency'] = merged_df0['DivFrequency'].fillna(div_df1.iloc[0]['DivFrequency'])
    merged_df0['DivType'] = merged_df0['DivType'].fillna(div_df1.iloc[0]['DivType'])
    merged_df0['DivPayDeclared'] = merged_df0['DivAmount'].fillna(0)

    div_var = 0

    for index1, row1 in merged_df0.iterrows():
        if row1['DivAmount'] > 0:
            div_var = row1['DivAmount']

        else:
            merged_df0.at[index1, 'DivAmount'] = div_var

    merged_df0['FwdDiv'] = merged_df0['DivFrequency'] * merged_df0['DivAmount']
    merged_df0['FwdDivYield'] = merged_df0['FwdDiv'] / merged_df0['PricePerShare']

    aggr_df0 = merged_df0
    aggr_df0 = aggr_df0.set_index('Date')
    aggr_df1 = aggr_df0.groupby(aggr_df0.index.year).agg(
        SharePriceMin=pd.NamedAgg(column='PricePerShare', aggfunc='min'),
        SharePriceMax=pd.NamedAgg(column='PricePerShare', aggfunc='max'),
        SharePriceMean=pd.NamedAgg(column='PricePerShare', aggfunc='mean'),
        SharePriceMedian=pd.NamedAgg(column='PricePerShare', aggfunc='median'),
        DivYieldMin=pd.NamedAgg(column='FwdDivYield', aggfunc='min'),
        DivYieldMax=pd.NamedAgg(column='FwdDivYield', aggfunc='max'),
        DivYieldMean=pd.NamedAgg(column='FwdDivYield', aggfunc='mean'),
        DivYieldMedian=pd.NamedAgg(column='FwdDivYield', aggfunc='median'),
        DivPaidTotal=pd.NamedAgg('DivPayDeclared', aggfunc='sum')
    )

    aggr_df1.index.name = 'DateCy'

    merged_df0.to_csv(os.path.join(path_ticker, row['Ticker'].upper() + '--DivPrice_History--s3v1.csv'))
    aggr_df1.to_csv(os.path.join(path_ticker, row['Ticker'].upper() + '--Aggregate_Cy_DivPrice_History--s4v1.csv'))

    print(row['Ticker'] + '--Completed')
# Out:
# AAPL--Start
# AAPL--Completed
# ABBV--Start
# ABBV--Completed
# ADM--Start
# ADM--Completed
# ADP--Start
# ADP--Completed
# AMT--Start
# AMT--Completed
# AOS--Start
# AOS--Completed
# ASML--Start
# ASML--Completed
# AVGO--Start
# AVGO--Completed
# AWK--Start
# AWK--Completed
# BBY--Start
# BBY--Completed
# BF.A--Start
# BF.A--Completed
# BLK--Start
# BLK--Completed
# BMY--Start
# BMY--Completed
# CAT--Start
# CAT--Completed
# CCI--Start
# CCI--Completed
# CL--Start
# CL--Completed
# CLX--Start
# CLX--Completed
# CMCSA--Start
# CMCSA--Completed
# CNI--Start
# CNI--Completed
# COST--Start
# COST--Completed
# CPB--Start
# CPB--Completed
# CVS--Start
# CVS--Completed
# CVX--Start
# CVX--Completed
# D--Start
# D--Completed
# DE--Start
# DE--Completed
# DEO--Start
# DEO--Completed
# DLR--Start
# DLR--Completed
# DOW--Start
# DOW--Completed
# DUK--Start
# DUK--Completed
# ED--Start
# ED--Completed
# EMN--Start
# EMN--Completed
# EOG--Start
# EOG--Completed
# EQIX--Start
# EQIX--Completed
# FAST--Start
# FAST--Completed
# FDX--Start
# FDX--Completed
# FLO--Start
# FLO--Completed
# GD--Start
# GD--Completed
# GIS--Start
# GIS--Completed
# HD--Start
# HD--Completed
# HRL--Start
# HRL--Completed
# HSY--Start
# HSY--Completed
# INTC--Start
# INTC--Completed
# INTU--Start
# INTU--Completed
# IRM--Start
# IRM--Completed
# JNJ--Start
# JNJ--Completed
# KMB--Start
# KMB--Completed
# KO--Start
# KO--Completed
# LLY--Start
# LLY--Completed
# LMT--Start
# LMT--Completed
# LOW--Start
# LOW--Completed
# LRCX--Start
# LRCX--Completed
# LYB--Start
# LYB--Completed
# MAN--Start
# MAN--Completed
# MCD--Start
# MCD--Completed
# MDLZ--Start
# MDLZ--Completed
# MDT--Start
# MDT--Completed
# MKC.V--Start
# MKC.V--Completed
# MMM--Start
# MMM--Completed
# MO--Start
# MO--Completed
# MRK--Start
# MRK--Completed
# MSFT--Start
# MSFT--Completed
# NKE--Start
# NKE--Completed
# NOC--Start
# NOC--Completed
# NVDA--Start
# NVDA--Completed
# O--Start
# O--Completed
# PEP--Start
# PEP--Completed
# PFE--Start
# PFE--Completed
# QCOM--Start
# QCOM--Completed
# SCHW--Start
# SCHW--Completed
# SHW--Start
# SHW--Completed
# SJM--Start
# SJM--Completed
# SNA--Start
# SNA--Completed
# SO--Start
# SO--Completed
# SPG--Start
# SPG--Completed
# SPGI--Start
# SPGI--Completed
# T--Start
# T--Completed
# TGT--Start
# TGT--Completed
# TROW--Start
# TROW--Completed
# TSM--Start
# TSM--Completed
# TSN--Start
# TSN--Completed
# TXN--Start
# TXN--Completed
# UNH--Start
# UNH--Completed
# UNP--Start
# UNP--Completed
# UPS--Start
# UPS--Completed
# V--Start
# V--Completed
# VZ--Start
# VZ--Completed
# WMT--Start
# WMT--Completed
# XOM--Start
# XOM--Completed
# ZTS--Start
# ZTS--Completed
