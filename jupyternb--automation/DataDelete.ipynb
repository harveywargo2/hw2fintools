# %%
from hw2fintools import gurufocus as gf
import hw2fintools as ft
import os
from dotenv import load_dotenv

load_dotenv()
# Common Variables & Dataframes
path_stockdata = os.path.join(os.environ.get('judgement_day'), 'Data--StockWatchList')
df_0 = ft.get_df_stock_watch_list()
ticker_list = df_0['Ticker']
gt = os.environ.get('guru_token')

# %%
for ticker in ticker_list:
    path_ticker = os.path.join(path_stockdata, ticker.upper())

    print(f'Start--{ticker}')

    for item in os.listdir(path_ticker):
        if item.startswith(ticker):
            file_path = os.path.join(path_ticker, item)
            os.remove(file_path)
            print(f'{file_path}')
# Out:
# Start--AAPL
# Start--ABBV
# Start--ADM
# Start--ADP
# Start--AMD
# Start--AMT
# Start--AMZN
# Start--AOS
# Start--ASML
# Start--AVGO
# Start--AWK
# Start--BBY
# Start--BF.A
# Start--BLK
# Start--BMY
# Start--CAT
# Start--CCI
# Start--CL
# /Volumes/JudgmentDay/Data--StockWatchList/CL/CL--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/CL/CL--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/CL/CL--Annual_10K--s5v1.csv
# Start--CLX
# /Volumes/JudgmentDay/Data--StockWatchList/CLX/CLX--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/CLX/CLX--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/CLX/CLX--Annual_10K--s5v1.csv
# Start--CMCSA
# /Volumes/JudgmentDay/Data--StockWatchList/CMCSA/CMCSA--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/CMCSA/CMCSA--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/CMCSA/CMCSA--Annual_10K--s5v1.csv
# Start--CNI
# /Volumes/JudgmentDay/Data--StockWatchList/CNI/CNI--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/CNI/CNI--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/CNI/CNI--Annual_10K--s5v1.csv
# Start--COST
# /Volumes/JudgmentDay/Data--StockWatchList/COST/COST--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/COST/COST--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/COST/COST--Annual_10K--s5v1.csv
# Start--CPB
# /Volumes/JudgmentDay/Data--StockWatchList/CPB/CPB--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/CPB/CPB--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/CPB/CPB--Annual_10K--s5v1.csv
# Start--CVS
# /Volumes/JudgmentDay/Data--StockWatchList/CVS/CVS--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/CVS/CVS--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/CVS/CVS--Annual_10K--s5v1.csv
# Start--CVX
# /Volumes/JudgmentDay/Data--StockWatchList/CVX/CVX--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/CVX/CVX--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/CVX/CVX--Annual_10K--s5v1.csv
# Start--D
# /Volumes/JudgmentDay/Data--StockWatchList/D/D--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/D/D--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/D/D--Annual_10K--s5v1.csv
# Start--DE
# /Volumes/JudgmentDay/Data--StockWatchList/DE/DE--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/DE/DE--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/DE/DE--Annual_10K--s5v1.csv
# Start--DEO
# /Volumes/JudgmentDay/Data--StockWatchList/DEO/DEO--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/DEO/DEO--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/DEO/DEO--Annual_10K--s5v1.csv
# Start--DLR
# /Volumes/JudgmentDay/Data--StockWatchList/DLR/DLR--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/DLR/DLR--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/DLR/DLR--Annual_10K--s5v1.csv
# Start--DOW
# /Volumes/JudgmentDay/Data--StockWatchList/DOW/DOW--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/DOW/DOW--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/DOW/DOW--Annual_10K--s5v1.csv
# Start--DUK
# /Volumes/JudgmentDay/Data--StockWatchList/DUK/DUK--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/DUK/DUK--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/DUK/DUK--Annual_10K--s5v1.csv
# Start--ED
# /Volumes/JudgmentDay/Data--StockWatchList/ED/ED--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/ED/ED--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/ED/ED--Annual_10K--s5v1.csv
# Start--EMN
# /Volumes/JudgmentDay/Data--StockWatchList/EMN/EMN--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/EMN/EMN--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/EMN/EMN--Annual_10K--s5v1.csv
# Start--EOG
# /Volumes/JudgmentDay/Data--StockWatchList/EOG/EOG--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/EOG/EOG--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/EOG/EOG--Annual_10K--s5v1.csv
# Start--EQIX
# /Volumes/JudgmentDay/Data--StockWatchList/EQIX/EQIX--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/EQIX/EQIX--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/EQIX/EQIX--Annual_10K--s5v1.csv
# Start--FAST
# /Volumes/JudgmentDay/Data--StockWatchList/FAST/FAST--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/FAST/FAST--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/FAST/FAST--Annual_10K--s5v1.csv
# Start--FDX
# /Volumes/JudgmentDay/Data--StockWatchList/FDX/FDX--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/FDX/FDX--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/FDX/FDX--Annual_10K--s5v1.csv
# Start--FLO
# /Volumes/JudgmentDay/Data--StockWatchList/FLO/FLO--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/FLO/FLO--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/FLO/FLO--Annual_10K--s5v1.csv
# Start--GD
# /Volumes/JudgmentDay/Data--StockWatchList/GD/GD--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/GD/GD--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/GD/GD--Annual_10K--s5v1.csv
# Start--GIS
# /Volumes/JudgmentDay/Data--StockWatchList/GIS/GIS--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/GIS/GIS--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/GIS/GIS--Annual_10K--s5v1.csv
# Start--GOOGL
# /Volumes/JudgmentDay/Data--StockWatchList/GOOGL/GOOGL--Annual_10K--s5v1.csv
# Start--HD
# /Volumes/JudgmentDay/Data--StockWatchList/HD/HD--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/HD/HD--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/HD/HD--Annual_10K--s5v1.csv
# Start--HRL
# /Volumes/JudgmentDay/Data--StockWatchList/HRL/HRL--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/HRL/HRL--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/HRL/HRL--Annual_10K--s5v1.csv
# Start--HSY
# /Volumes/JudgmentDay/Data--StockWatchList/HSY/HSY--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/HSY/HSY--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/HSY/HSY--Annual_10K--s5v1.csv
# Start--INTC
# /Volumes/JudgmentDay/Data--StockWatchList/INTC/INTC--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/INTC/INTC--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/INTC/INTC--Annual_10K--s5v1.csv
# Start--INTU
# /Volumes/JudgmentDay/Data--StockWatchList/INTU/INTU--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/INTU/INTU--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/INTU/INTU--Annual_10K--s5v1.csv
# Start--IRM
# /Volumes/JudgmentDay/Data--StockWatchList/IRM/IRM--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/IRM/IRM--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/IRM/IRM--Annual_10K--s5v1.csv
# Start--ITW
# /Volumes/JudgmentDay/Data--StockWatchList/ITW/ITW--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/ITW/ITW--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/ITW/ITW--Annual_10K--s5v1.csv
# Start--JNJ
# /Volumes/JudgmentDay/Data--StockWatchList/JNJ/JNJ--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/JNJ/JNJ--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/JNJ/JNJ--Annual_10K--s5v1.csv
# Start--KMB
# /Volumes/JudgmentDay/Data--StockWatchList/KMB/KMB--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/KMB/KMB--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/KMB/KMB--Annual_10K--s5v1.csv
# Start--KO
# /Volumes/JudgmentDay/Data--StockWatchList/KO/KO--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/KO/KO--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/KO/KO--Annual_10K--s5v1.csv
# Start--LLY
# /Volumes/JudgmentDay/Data--StockWatchList/LLY/LLY--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/LLY/LLY--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/LLY/LLY--Annual_10K--s5v1.csv
# Start--LMT
# /Volumes/JudgmentDay/Data--StockWatchList/LMT/LMT--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/LMT/LMT--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/LMT/LMT--Annual_10K--s5v1.csv
# Start--LOW
# /Volumes/JudgmentDay/Data--StockWatchList/LOW/LOW--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/LOW/LOW--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/LOW/LOW--Annual_10K--s5v1.csv
# Start--LRCX
# /Volumes/JudgmentDay/Data--StockWatchList/LRCX/LRCX--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/LRCX/LRCX--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/LRCX/LRCX--Annual_10K--s5v1.csv
# Start--LYB
# /Volumes/JudgmentDay/Data--StockWatchList/LYB/LYB--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/LYB/LYB--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/LYB/LYB--Annual_10K--s5v1.csv
# Start--MAN
# /Volumes/JudgmentDay/Data--StockWatchList/MAN/MAN--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/MAN/MAN--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/MAN/MAN--Annual_10K--s5v1.csv
# Start--MCD
# /Volumes/JudgmentDay/Data--StockWatchList/MCD/MCD--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/MCD/MCD--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/MCD/MCD--Annual_10K--s5v1.csv
# Start--MCO
# /Volumes/JudgmentDay/Data--StockWatchList/MCO/MCO--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/MCO/MCO--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/MCO/MCO--Annual_10K--s5v1.csv
# Start--MDLZ
# /Volumes/JudgmentDay/Data--StockWatchList/MDLZ/MDLZ--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/MDLZ/MDLZ--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/MDLZ/MDLZ--Annual_10K--s5v1.csv
# Start--MDT
# /Volumes/JudgmentDay/Data--StockWatchList/MDT/MDT--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/MDT/MDT--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/MDT/MDT--Annual_10K--s5v1.csv
# Start--META
# /Volumes/JudgmentDay/Data--StockWatchList/META/META--Annual_10K--s5v1.csv
# Start--MKC.V
# /Volumes/JudgmentDay/Data--StockWatchList/MKC.V/MKC.V--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/MKC.V/MKC.V--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/MKC.V/MKC.V--Annual_10K--s5v1.csv
# Start--MMM
# /Volumes/JudgmentDay/Data--StockWatchList/MMM/MMM--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/MMM/MMM--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/MMM/MMM--Annual_10K--s5v1.csv
# Start--MO
# /Volumes/JudgmentDay/Data--StockWatchList/MO/MO--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/MO/MO--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/MO/MO--Annual_10K--s5v1.csv
# Start--MRK
# /Volumes/JudgmentDay/Data--StockWatchList/MRK/MRK--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/MRK/MRK--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/MRK/MRK--Annual_10K--s5v1.csv
# Start--MSFT
# /Volumes/JudgmentDay/Data--StockWatchList/MSFT/MSFT--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/MSFT/MSFT--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/MSFT/MSFT--Annual_10K--s5v1.csv
# Start--NKE
# /Volumes/JudgmentDay/Data--StockWatchList/NKE/NKE--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/NKE/NKE--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/NKE/NKE--Annual_10K--s5v1.csv
# Start--NOC
# /Volumes/JudgmentDay/Data--StockWatchList/NOC/NOC--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/NOC/NOC--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/NOC/NOC--Annual_10K--s5v1.csv
# Start--NVDA
# /Volumes/JudgmentDay/Data--StockWatchList/NVDA/NVDA--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/NVDA/NVDA--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/NVDA/NVDA--Annual_10K--s5v1.csv
# Start--O
# /Volumes/JudgmentDay/Data--StockWatchList/O/O--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/O/O--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/O/O--Annual_10K--s5v1.csv
# Start--PEP
# /Volumes/JudgmentDay/Data--StockWatchList/PEP/PEP--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/PEP/PEP--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/PEP/PEP--Annual_10K--s5v1.csv
# Start--PFE
# /Volumes/JudgmentDay/Data--StockWatchList/PFE/PFE--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/PFE/PFE--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/PFE/PFE--Annual_10K--s5v1.csv
# Start--PM
# /Volumes/JudgmentDay/Data--StockWatchList/PM/PM--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/PM/PM--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/PM/PM--Annual_10K--s5v1.csv
# Start--PPG
# /Volumes/JudgmentDay/Data--StockWatchList/PPG/PPG--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/PPG/PPG--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/PPG/PPG--Annual_10K--s5v1.csv
# Start--QCOM
# /Volumes/JudgmentDay/Data--StockWatchList/QCOM/QCOM--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/QCOM/QCOM--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/QCOM/QCOM--Annual_10K--s5v1.csv
# Start--SBUX
# /Volumes/JudgmentDay/Data--StockWatchList/SBUX/SBUX--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/SBUX/SBUX--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/SBUX/SBUX--Annual_10K--s5v1.csv
# Start--SCHW
# /Volumes/JudgmentDay/Data--StockWatchList/SCHW/SCHW--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/SCHW/SCHW--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/SCHW/SCHW--Annual_10K--s5v1.csv
# Start--SHW
# /Volumes/JudgmentDay/Data--StockWatchList/SHW/SHW--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/SHW/SHW--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/SHW/SHW--Annual_10K--s5v1.csv
# Start--SJM
# /Volumes/JudgmentDay/Data--StockWatchList/SJM/SJM--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/SJM/SJM--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/SJM/SJM--Annual_10K--s5v1.csv
# Start--SNA
# /Volumes/JudgmentDay/Data--StockWatchList/SNA/SNA--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/SNA/SNA--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/SNA/SNA--Annual_10K--s5v1.csv
# Start--SO
# /Volumes/JudgmentDay/Data--StockWatchList/SO/SO--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/SO/SO--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/SO/SO--Annual_10K--s5v1.csv
# Start--SPG
# /Volumes/JudgmentDay/Data--StockWatchList/SPG/SPG--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/SPG/SPG--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/SPG/SPG--Annual_10K--s5v1.csv
# Start--SPGI
# /Volumes/JudgmentDay/Data--StockWatchList/SPGI/SPGI--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/SPGI/SPGI--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/SPGI/SPGI--Annual_10K--s5v1.csv
# Start--T
# /Volumes/JudgmentDay/Data--StockWatchList/T/T--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/T/T--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/T/T--Annual_10K--s5v1.csv
# Start--TGT
# /Volumes/JudgmentDay/Data--StockWatchList/TGT/TGT--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/TGT/TGT--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/TGT/TGT--Annual_10K--s5v1.csv
# Start--TROW
# /Volumes/JudgmentDay/Data--StockWatchList/TROW/TROW--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/TROW/TROW--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/TROW/TROW--Annual_10K--s5v1.csv
# Start--TSCO
# /Volumes/JudgmentDay/Data--StockWatchList/TSCO/TSCO--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/TSCO/TSCO--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/TSCO/TSCO--Annual_10K--s5v1.csv
# Start--TSM
# /Volumes/JudgmentDay/Data--StockWatchList/TSM/TSM--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/TSM/TSM--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/TSM/TSM--Annual_10K--s5v1.csv
# Start--TSN
# /Volumes/JudgmentDay/Data--StockWatchList/TSN/TSN--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/TSN/TSN--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/TSN/TSN--Annual_10K--s5v1.csv
# Start--TXN
# /Volumes/JudgmentDay/Data--StockWatchList/TXN/TXN--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/TXN/TXN--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/TXN/TXN--Annual_10K--s5v1.csv
# Start--UNH
# /Volumes/JudgmentDay/Data--StockWatchList/UNH/UNH--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/UNH/UNH--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/UNH/UNH--Annual_10K--s5v1.csv
# Start--UNP
# /Volumes/JudgmentDay/Data--StockWatchList/UNP/UNP--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/UNP/UNP--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/UNP/UNP--Annual_10K--s5v1.csv
# Start--UPS
# /Volumes/JudgmentDay/Data--StockWatchList/UPS/UPS--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/UPS/UPS--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/UPS/UPS--Annual_10K--s5v1.csv
# Start--V
# /Volumes/JudgmentDay/Data--StockWatchList/V/V--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/V/V--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/V/V--Annual_10K--s5v1.csv
# Start--VICI
# /Volumes/JudgmentDay/Data--StockWatchList/VICI/VICI--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/VICI/VICI--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/VICI/VICI--Annual_10K--s5v1.csv
# Start--VZ
# /Volumes/JudgmentDay/Data--StockWatchList/VZ/VZ--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/VZ/VZ--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/VZ/VZ--Annual_10K--s5v1.csv
# Start--WMT
# /Volumes/JudgmentDay/Data--StockWatchList/WMT/WMT--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/WMT/WMT--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/WMT/WMT--Annual_10K--s5v1.csv
# Start--XOM
# /Volumes/JudgmentDay/Data--StockWatchList/XOM/XOM--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/XOM/XOM--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/XOM/XOM--Annual_10K--s5v1.csv
# Start--ZTS
# /Volumes/JudgmentDay/Data--StockWatchList/ZTS/ZTS--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/ZTS/ZTS--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/ZTS/ZTS--Annual_10K--s5v1.csv
# Start--NSRGY
# /Volumes/JudgmentDay/Data--StockWatchList/NSRGY/NSRGY--DivPrice_History--s3v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/NSRGY/NSRGY--Aggregate_Cy_DivPrice_History--s4v1.csv
# /Volumes/JudgmentDay/Data--StockWatchList/NSRGY/NSRGY--Annual_10K--s5v1.csv
